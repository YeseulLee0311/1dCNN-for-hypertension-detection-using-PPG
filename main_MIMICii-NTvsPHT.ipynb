# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/ECE271B_project/
# Out:
# /content/drive/MyDrive/ECE271B_project

# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from modules import train_model, test_model
from dataset import BPDataset, MIMICDataset
from torch import optim
from torch.optim import lr_scheduler
from datetime import datetime
import pandas as pd
from backbone_models import ResNet18, VGG16, shallowResNet, shallowResNet2,ResNet3, FCNet, Conv3Net
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.utils.data as data

# %%
##Dataset paths from part1 to part4
'''data_path=['/Users/yeseullee/Documents/ECE271B/MIMICii/part1',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part2',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part3',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part4']

label_path=['/Users/yeseullee/Documents/ECE271B/MIMICii/part1/label1.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part2/label2.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part3/label3.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part4/label4.csv']'''
data_path='/content/drive/MyDrive/ECE271B_project/MIMICii/dataset_NT_PHT.pt'
label_path='/content/drive/MyDrive/ECE271B_project/MIMICii/label_NT_PHT.pt'
subject_path='/content/drive/MyDrive/ECE271B_project/MIMICii/subjectid_NT_PHT.txt'

# %%
data_mean=1.59
data_std=0.73
data_normalization = {'mean':data_mean,'std':data_std}

# setup data loader
dataset = MIMICDataset(data_path, label_path, subject_path, normalize=data_normalization,preprocessing=False, choose_class=[0,1])
dataset_size=dataset.__len__()
print('dataset: {}'.format(dataset.__len__()))
# Out:
# dataset: 329514

# %%
training_size=int(dataset_size*0.64)
test_size=int(dataset_size*0.2)
val_size=dataset_size-training_size-test_size

# %%
# Split training data, validation data, testing data
data_train, data_val, data_test = torch.utils.data.random_split(dataset, [training_size, val_size, test_size])
print(data_train.__len__())
print(data_val.__len__())
print(data_test.__len__())
# Out:
# 210888
# 52724
# 65902

# %%
temp_dataloaders={'train': torch.utils.data.DataLoader(data_train,batch_size=1,shuffle=False),
                'val':torch.utils.data.DataLoader(data_val,batch_size=1,shuffle=False),
                'test':torch.utils.data.DataLoader(data_test,batch_size=1,shuffle=False)}

train_labels=[0,0,0]
for data, label, subject in temp_dataloaders['train']:
    if label.data==0:
        train_labels[0]+=1
    elif label.data==1:
        train_labels[1]+=1
    else:
        train_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),train_labels,color=['g','b','r'],width=0.7)
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Training-set Class Distribution')
plt.show()

val_labels=[0,0,0]
for data, label, subject in temp_dataloaders['val']:
    if label.data==0:
        val_labels[0]+=1
    elif label.data==1:
        val_labels[1]+=1
    else:
        val_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),val_labels,color=['g','b','r'])
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Validation-set Class Distribution')
plt.show()

test_labels=[0,0,0]
for data, label, subject in temp_dataloaders['test']:
    if label.data==0:
        test_labels[0]+=1
    elif label.data==1:
        test_labels[1]+=1
    else:
        test_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),test_labels,color=['g','b','r'])
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Test-set Class Distribution')
plt.show()

# %%
dataloaders={'train': torch.utils.data.DataLoader(data_train,batch_size=32,shuffle=True),
                'val':torch.utils.data.DataLoader(data_val,batch_size=32,shuffle=True),
                'test':torch.utils.data.DataLoader(data_test,batch_size=32,shuffle=False)}
dataset_sizes = {'train': data_train.__len__(),
                    'val':data_val.__len__(),
                    'test':data_test.__len__()}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device:',device)
# Out:
# Device: cuda

# %%
model=Conv3Net(2)
model=model.to(device)

# %%
learning_rate=0.001
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0005)
#optimizer = optim.Adam(model.parameters(), lr=learning_rate) #weight_decay=0.01
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.2)
trained_model,trained_model_later=train_model(model, criterion, optimizer, exp_lr_scheduler, dataloaders, dataset_sizes, device, num_epochs=150)
# Out:
# Epoch 0/149
# ----------
# train Loss: 0.6653 Acc: 0.5882
# val Loss: 0.6372 Acc: 0.6356
#
# Epoch 1/149
# ----------
# train Loss: 0.6254 Acc: 0.6425
# val Loss: 0.6061 Acc: 0.6590
#
# Epoch 2/149
# ----------
# train Loss: 0.6041 Acc: 0.6675
# val Loss: 0.5913 Acc: 0.6766
#
# Epoch 3/149
# ----------
# train Loss: 0.5893 Acc: 0.6787
# val Loss: 0.5841 Acc: 0.6798
#
# Epoch 4/149
# ----------
# train Loss: 0.5766 Acc: 0.6885
# val Loss: 0.5623 Acc: 0.7021
#
# Epoch 5/149
# ----------
# train Loss: 0.5674 Acc: 0.6967
# val Loss: 0.5521 Acc: 0.7065
#
# Epoch 6/149
# ----------
# train Loss: 0.5589 Acc: 0.7038
# val Loss: 0.5580 Acc: 0.6945
#
# Epoch 7/149
# ----------
# train Loss: 0.5517 Acc: 0.7094
# val Loss: 0.5457 Acc: 0.7083
#
# Epoch 8/149
# ----------
# train Loss: 0.5456 Acc: 0.7137
# val Loss: 0.5400 Acc: 0.7219
#
# Epoch 9/149
# ----------
# train Loss: 0.5422 Acc: 0.7160
# val Loss: 0.5487 Acc: 0.7087
#
# Epoch 10/149
# ----------
# train Loss: 0.5381 Acc: 0.7192
# val Loss: 0.5469 Acc: 0.7143
#
# Epoch 11/149
# ----------
# train Loss: 0.5344 Acc: 0.7222
# val Loss: 0.5385 Acc: 0.7160
#
# Epoch 12/149
# ----------
# train Loss: 0.5314 Acc: 0.7241
# val Loss: 0.5344 Acc: 0.7121
#
# Epoch 13/149
# ----------
# train Loss: 0.5289 Acc: 0.7249
# val Loss: 0.5432 Acc: 0.7133
#
# Epoch 14/149
# ----------
# train Loss: 0.5265 Acc: 0.7276
# val Loss: 0.5161 Acc: 0.7322
#
# Epoch 15/149
# ----------
# train Loss: 0.5245 Acc: 0.7285
# val Loss: 0.5357 Acc: 0.7168
#
# Epoch 16/149
# ----------
# train Loss: 0.5210 Acc: 0.7321
# val Loss: 0.5203 Acc: 0.7342
#
# Epoch 17/149
# ----------
# train Loss: 0.5193 Acc: 0.7335
# val Loss: 0.5095 Acc: 0.7384
#
# Epoch 18/149
# ----------
# train Loss: 0.5187 Acc: 0.7336
# val Loss: 0.5281 Acc: 0.7260
#
# Epoch 19/149
# ----------
# train Loss: 0.5172 Acc: 0.7353
# val Loss: 0.5365 Acc: 0.7174
#
# Epoch 20/149
# ----------
# train Loss: 0.5158 Acc: 0.7354
# val Loss: 0.5280 Acc: 0.7286
#
# Epoch 21/149
# ----------
# train Loss: 0.5137 Acc: 0.7375
# val Loss: 0.5313 Acc: 0.7235
#
# Epoch 22/149
# ----------
# train Loss: 0.5126 Acc: 0.7379
# val Loss: 0.5194 Acc: 0.7343
#
# Epoch 23/149
# ----------
# train Loss: 0.5113 Acc: 0.7382
# val Loss: 0.5074 Acc: 0.7422
#
# Epoch 24/149
# ----------
# train Loss: 0.5102 Acc: 0.7393
# val Loss: 0.5313 Acc: 0.7263
#
# Epoch 25/149
# ----------
# train Loss: 0.5097 Acc: 0.7399
# val Loss: 0.5241 Acc: 0.7317
#
# Epoch 26/149
# ----------
# train Loss: 0.5090 Acc: 0.7404
# val Loss: 0.5177 Acc: 0.7324
#
# Epoch 27/149
# ----------
# train Loss: 0.5070 Acc: 0.7419
# val Loss: 0.5044 Acc: 0.7426
#
# Epoch 28/149
# ----------
# train Loss: 0.5064 Acc: 0.7432
# val Loss: 0.5134 Acc: 0.7317
#
# Epoch 29/149
# ----------
# train Loss: 0.5062 Acc: 0.7419
# val Loss: 0.5096 Acc: 0.7381
#
# Epoch 30/149
# ----------
# train Loss: 0.4345 Acc: 0.7894
# val Loss: 0.4570 Acc: 0.7744
#
# Epoch 31/149
# ----------
# train Loss: 0.4172 Acc: 0.7998
# val Loss: 0.4555 Acc: 0.7779
#
# Epoch 32/149
# ----------
# train Loss: 0.4064 Acc: 0.8069
# val Loss: 0.4502 Acc: 0.7820
#
# Epoch 33/149
# ----------
# train Loss: 0.3995 Acc: 0.8116
# val Loss: 0.4510 Acc: 0.7797
#
# Epoch 34/149
# ----------
# train Loss: 0.3931 Acc: 0.8157
# val Loss: 0.4473 Acc: 0.7853
#
# Epoch 35/149
# ----------
# train Loss: 0.3879 Acc: 0.8185
# val Loss: 0.4478 Acc: 0.7851
#
# Epoch 36/149
# ----------
# train Loss: 0.3840 Acc: 0.8198
# val Loss: 0.4510 Acc: 0.7844
#
# Epoch 37/149
# ----------
# train Loss: 0.3810 Acc: 0.8220
# val Loss: 0.4482 Acc: 0.7875
#
# Epoch 38/149
# ----------
# train Loss: 0.3766 Acc: 0.8248
# val Loss: 0.4627 Acc: 0.7794
#
# Epoch 39/149
# ----------
# train Loss: 0.3752 Acc: 0.8260
# val Loss: 0.4446 Acc: 0.7878
#
# Epoch 40/149
# ----------
# train Loss: 0.3710 Acc: 0.8274
# val Loss: 0.4534 Acc: 0.7824
#
# Epoch 41/149
# ----------
# train Loss: 0.3691 Acc: 0.8293
# val Loss: 0.4560 Acc: 0.7852
#
# Epoch 42/149
# ----------
# train Loss: 0.3682 Acc: 0.8299
# val Loss: 0.4522 Acc: 0.7910
#
# Epoch 43/149
# ----------
# train Loss: 0.3656 Acc: 0.8311
# val Loss: 0.4583 Acc: 0.7836
#
# Epoch 44/149
# ----------
# train Loss: 0.3637 Acc: 0.8324
# val Loss: 0.4522 Acc: 0.7862
#
# Epoch 45/149
# ----------
# train Loss: 0.3625 Acc: 0.8322
# val Loss: 0.4584 Acc: 0.7856
#
# Epoch 46/149
# ----------
# train Loss: 0.3604 Acc: 0.8343
# val Loss: 0.4591 Acc: 0.7861
#
# Epoch 47/149
# ----------
# train Loss: 0.3587 Acc: 0.8351
# val Loss: 0.4603 Acc: 0.7826
#
# Epoch 48/149
# ----------
# train Loss: 0.3574 Acc: 0.8355
# val Loss: 0.4529 Acc: 0.7880
#
# Epoch 49/149
# ----------
# train Loss: 0.3562 Acc: 0.8364
# val Loss: 0.4501 Acc: 0.7878
#
# Epoch 50/149
# ----------
# train Loss: 0.3546 Acc: 0.8375
# val Loss: 0.4547 Acc: 0.7882
#
# Epoch 51/149
# ----------
# train Loss: 0.3532 Acc: 0.8386
# val Loss: 0.4432 Acc: 0.7933
#
# Epoch 52/149
# ----------
# train Loss: 0.3524 Acc: 0.8390
# val Loss: 0.4492 Acc: 0.7893
#
# Epoch 53/149
# ----------
# train Loss: 0.3506 Acc: 0.8395
# val Loss: 0.4543 Acc: 0.7863
#
# Epoch 54/149
# ----------
# train Loss: 0.3493 Acc: 0.8402
# val Loss: 0.4572 Acc: 0.7868
#
# Epoch 55/149
# ----------
# train Loss: 0.3479 Acc: 0.8407
# val Loss: 0.4606 Acc: 0.7854
#
# Epoch 56/149
# ----------
# train Loss: 0.3472 Acc: 0.8415
# val Loss: 0.4585 Acc: 0.7819
#
# Epoch 57/149
# ----------
# train Loss: 0.3453 Acc: 0.8425
# val Loss: 0.4600 Acc: 0.7885
#
# Epoch 58/149
# ----------
# train Loss: 0.3443 Acc: 0.8431
# val Loss: 0.4591 Acc: 0.7882
#
# Epoch 59/149
# ----------
# train Loss: 0.3431 Acc: 0.8433
# val Loss: 0.4545 Acc: 0.7898
#
# Epoch 60/149
# ----------
# train Loss: 0.2890 Acc: 0.8742
# val Loss: 0.4485 Acc: 0.8026
#
# Epoch 61/149
# ----------
# train Loss: 0.2797 Acc: 0.8784
# val Loss: 0.4507 Acc: 0.8008
#
# Epoch 62/149
# ----------
# train Loss: 0.2754 Acc: 0.8805
# val Loss: 0.4547 Acc: 0.8011
#
# Epoch 63/149
# ----------
# train Loss: 0.2728 Acc: 0.8814
# val Loss: 0.4589 Acc: 0.8005
#
# Epoch 64/149
# ----------
# train Loss: 0.2703 Acc: 0.8836
# val Loss: 0.4599 Acc: 0.8005
#
# Epoch 65/149
# ----------
# train Loss: 0.2676 Acc: 0.8845
# val Loss: 0.4647 Acc: 0.8000
#
# Epoch 66/149
# ----------
# train Loss: 0.2662 Acc: 0.8853
# val Loss: 0.4647 Acc: 0.8002
#
# Epoch 67/149
# ----------
# train Loss: 0.2643 Acc: 0.8863
# val Loss: 0.4661 Acc: 0.8008
#
# Epoch 68/149
# ----------
# train Loss: 0.2628 Acc: 0.8873
# val Loss: 0.4683 Acc: 0.8002
#
# Epoch 69/149
# ----------
# train Loss: 0.2614 Acc: 0.8874
# val Loss: 0.4708 Acc: 0.8014
#
# Epoch 70/149
# ----------
# train Loss: 0.2597 Acc: 0.8884
# val Loss: 0.4750 Acc: 0.8008
#
# Epoch 71/149
# ----------
# train Loss: 0.2586 Acc: 0.8888
# val Loss: 0.4711 Acc: 0.7990
#
# Epoch 72/149
# ----------
# train Loss: 0.2571 Acc: 0.8894
# val Loss: 0.4759 Acc: 0.7999
#
# Epoch 73/149
# ----------
# train Loss: 0.2557 Acc: 0.8903
# val Loss: 0.4768 Acc: 0.7998
#
# Epoch 74/149
# ----------
# train Loss: 0.2544 Acc: 0.8909
# val Loss: 0.4801 Acc: 0.7992
#
# Epoch 75/149
# ----------
# train Loss: 0.2537 Acc: 0.8909
# val Loss: 0.4831 Acc: 0.7991
#
# Epoch 76/149
# ----------
# train Loss: 0.2518 Acc: 0.8927
# val Loss: 0.4875 Acc: 0.8005
#
# Epoch 77/149
# ----------
# train Loss: 0.2522 Acc: 0.8923
# val Loss: 0.4848 Acc: 0.7990
#
# Epoch 78/149
# ----------
# train Loss: 0.2503 Acc: 0.8926
# val Loss: 0.4794 Acc: 0.7995
#
# Epoch 79/149
# ----------
# train Loss: 0.2496 Acc: 0.8928
# val Loss: 0.4838 Acc: 0.7980
#
# Epoch 80/149
# ----------
# train Loss: 0.2489 Acc: 0.8937
# val Loss: 0.4888 Acc: 0.7979
#
# Epoch 81/149
# ----------
# train Loss: 0.2480 Acc: 0.8945
# val Loss: 0.4881 Acc: 0.7986
#
# Epoch 82/149
# ----------
# train Loss: 0.2470 Acc: 0.8951
# val Loss: 0.4961 Acc: 0.7982
#
# Epoch 83/149
# ----------
# train Loss: 0.2459 Acc: 0.8952
# val Loss: 0.4961 Acc: 0.7986
#
# Epoch 84/149
# ----------
# train Loss: 0.2451 Acc: 0.8954
# val Loss: 0.4934 Acc: 0.7985
#
# Epoch 85/149
# ----------
# train Loss: 0.2436 Acc: 0.8965
# val Loss: 0.4955 Acc: 0.7976
#
# Epoch 86/149
# ----------
# train Loss: 0.2433 Acc: 0.8965
# val Loss: 0.4962 Acc: 0.7977
#
# Epoch 87/149
# ----------
# train Loss: 0.2429 Acc: 0.8965
# val Loss: 0.5001 Acc: 0.7982
#
# Epoch 88/149
# ----------
# train Loss: 0.2418 Acc: 0.8971
# val Loss: 0.4997 Acc: 0.7982
#
# Epoch 89/149
# ----------
# train Loss: 0.2409 Acc: 0.8969
# val Loss: 0.4999 Acc: 0.7975
#
# Epoch 90/149
# ----------
# train Loss: 0.2297 Acc: 0.9043
# val Loss: 0.5037 Acc: 0.7997
#
# Epoch 91/149
# ----------
# train Loss: 0.2285 Acc: 0.9049
# val Loss: 0.5022 Acc: 0.7991
#
# Epoch 92/149
# ----------
# train Loss: 0.2282 Acc: 0.9050
# val Loss: 0.5058 Acc: 0.7981
#
# Epoch 93/149
# ----------
# train Loss: 0.2277 Acc: 0.9050
# val Loss: 0.5069 Acc: 0.7992
#
# Epoch 94/149
# ----------
# train Loss: 0.2275 Acc: 0.9051
# val Loss: 0.5072 Acc: 0.7981
#
# Epoch 95/149
# ----------
# train Loss: 0.2281 Acc: 0.9051
# val Loss: 0.5044 Acc: 0.7992
#
# Epoch 96/149
# ----------
# train Loss: 0.2268 Acc: 0.9057
# val Loss: 0.5076 Acc: 0.7981
#
# Epoch 97/149
# ----------
# train Loss: 0.2266 Acc: 0.9055
# val Loss: 0.5029 Acc: 0.7985
#
# Epoch 98/149
# ----------
# train Loss: 0.2269 Acc: 0.9055
# val Loss: 0.5092 Acc: 0.7983
#
# Epoch 99/149
# ----------
# train Loss: 0.2261 Acc: 0.9062
# val Loss: 0.5061 Acc: 0.7986
#
# Epoch 100/149
# ----------
# train Loss: 0.2263 Acc: 0.9058
# val Loss: 0.5096 Acc: 0.7985
#
# Epoch 101/149
# ----------
# train Loss: 0.2267 Acc: 0.9052
# val Loss: 0.5096 Acc: 0.7982
#
# Epoch 102/149
# ----------
# train Loss: 0.2257 Acc: 0.9061
# val Loss: 0.5113 Acc: 0.7977
#
# Epoch 103/149
# ----------
# train Loss: 0.2257 Acc: 0.9058
# val Loss: 0.5097 Acc: 0.7992
#
# Epoch 104/149
# ----------
# train Loss: 0.2253 Acc: 0.9068
# val Loss: 0.5097 Acc: 0.7982
#
# Epoch 105/149
# ----------
# train Loss: 0.2257 Acc: 0.9065
# val Loss: 0.5119 Acc: 0.7979
#
# Epoch 106/149
# ----------
# train Loss: 0.2257 Acc: 0.9054
# val Loss: 0.5082 Acc: 0.7985
#
# Epoch 107/149
# ----------
# train Loss: 0.2249 Acc: 0.9065
# val Loss: 0.5118 Acc: 0.7986
#
# Epoch 108/149
# ----------
# train Loss: 0.2256 Acc: 0.9061
# val Loss: 0.5134 Acc: 0.7980
#
# Epoch 109/149
# ----------
# train Loss: 0.2253 Acc: 0.9066
# val Loss: 0.5096 Acc: 0.7990
#
# Epoch 110/149
# ----------
# train Loss: 0.2250 Acc: 0.9065
# val Loss: 0.5127 Acc: 0.7984
#
# Epoch 111/149
# ----------
# train Loss: 0.2251 Acc: 0.9064
# val Loss: 0.5117 Acc: 0.7982
#
# Epoch 112/149
# ----------
# train Loss: 0.2251 Acc: 0.9062
# val Loss: 0.5134 Acc: 0.7979
#
# Epoch 113/149
# ----------
# train Loss: 0.2248 Acc: 0.9059
# val Loss: 0.5137 Acc: 0.7975
#
# Epoch 114/149
# ----------
# train Loss: 0.2250 Acc: 0.9062
# val Loss: 0.5120 Acc: 0.7976
#
# Epoch 115/149
# ----------
# train Loss: 0.2245 Acc: 0.9069
# val Loss: 0.5100 Acc: 0.7983
#
# Epoch 116/149
# ----------
# train Loss: 0.2240 Acc: 0.9064
# val Loss: 0.5151 Acc: 0.7980
#
# Epoch 117/149
# ----------
# train Loss: 0.2246 Acc: 0.9066
# val Loss: 0.5156 Acc: 0.7981
#
# Epoch 118/149
# ----------
# train Loss: 0.2239 Acc: 0.9068
# val Loss: 0.5138 Acc: 0.7985
#
# Epoch 119/149
# ----------
# train Loss: 0.2238 Acc: 0.9067
# val Loss: 0.5124 Acc: 0.7980
#
# Epoch 120/149
# ----------
# train Loss: 0.2225 Acc: 0.9080
# val Loss: 0.5128 Acc: 0.7986
#
# Epoch 121/149
# ----------
# train Loss: 0.2226 Acc: 0.9074
# val Loss: 0.5146 Acc: 0.7979
#
# Epoch 122/149
# ----------
# train Loss: 0.2224 Acc: 0.9077
# val Loss: 0.5132 Acc: 0.7980
#
# Epoch 123/149
# ----------
# train Loss: 0.2221 Acc: 0.9077
# val Loss: 0.5124 Acc: 0.7973
#
# Epoch 124/149
# ----------
# train Loss: 0.2226 Acc: 0.9071
# val Loss: 0.5145 Acc: 0.7983
#
# Epoch 125/149
# ----------
# train Loss: 0.2229 Acc: 0.9070
# val Loss: 0.5140 Acc: 0.7983
#
# Epoch 126/149
# ----------
# train Loss: 0.2226 Acc: 0.9075
# val Loss: 0.5125 Acc: 0.7984
#
# Epoch 127/149
# ----------
# train Loss: 0.2220 Acc: 0.9083
# val Loss: 0.5126 Acc: 0.7985
#
# Epoch 128/149
# ----------
# train Loss: 0.2220 Acc: 0.9082
# val Loss: 0.5142 Acc: 0.7983
#
# Epoch 129/149
# ----------
# train Loss: 0.2223 Acc: 0.9078
# val Loss: 0.5155 Acc: 0.7979
#
# Epoch 130/149
# ----------
# train Loss: 0.2225 Acc: 0.9076
# val Loss: 0.5140 Acc: 0.7973
#
# Epoch 131/149
# ----------
# train Loss: 0.2222 Acc: 0.9073
# val Loss: 0.5127 Acc: 0.7977
#
# Epoch 132/149
# ----------
# train Loss: 0.2226 Acc: 0.9079
# val Loss: 0.5143 Acc: 0.7981
#
# Epoch 133/149
# ----------
# train Loss: 0.2220 Acc: 0.9077
# val Loss: 0.5138 Acc: 0.7978
#
# Epoch 134/149
# ----------
# train Loss: 0.2224 Acc: 0.9075
# val Loss: 0.5141 Acc: 0.7983
#
# Epoch 135/149
# ----------
# train Loss: 0.2223 Acc: 0.9077
# val Loss: 0.5156 Acc: 0.7974
#
# Epoch 136/149
# ----------
# train Loss: 0.2222 Acc: 0.9076
# val Loss: 0.5147 Acc: 0.7980
#
# Epoch 137/149
# ----------
# train Loss: 0.2225 Acc: 0.9080
# val Loss: 0.5145 Acc: 0.7981
#
# Epoch 138/149
# ----------
# train Loss: 0.2221 Acc: 0.9077
# val Loss: 0.5169 Acc: 0.7978
#
# Epoch 139/149
# ----------
# train Loss: 0.2223 Acc: 0.9072
# val Loss: 0.5151 Acc: 0.7983
#
# Epoch 140/149
# ----------
# train Loss: 0.2222 Acc: 0.9075
# val Loss: 0.5156 Acc: 0.7980
#
# Epoch 141/149
# ----------
# train Loss: 0.2221 Acc: 0.9083
# val Loss: 0.5124 Acc: 0.7981
#
# Epoch 142/149
# ----------
# train Loss: 0.2219 Acc: 0.9081
# val Loss: 0.5152 Acc: 0.7983
#
# Epoch 143/149
# ----------
# train Loss: 0.2222 Acc: 0.9079
# val Loss: 0.5175 Acc: 0.7975
#
# Epoch 144/149
# ----------
# train Loss: 0.2225 Acc: 0.9079
# val Loss: 0.5145 Acc: 0.7980
#
# Epoch 145/149
# ----------
# train Loss: 0.2219 Acc: 0.9082
# val Loss: 0.5150 Acc: 0.7978
#
# Epoch 146/149
# ----------
# train Loss: 0.2218 Acc: 0.9074
# val Loss: 0.5160 Acc: 0.7977
#
# Epoch 147/149
# ----------
# train Loss: 0.2221 Acc: 0.9082
# val Loss: 0.5142 Acc: 0.7980
#
# Epoch 148/149
# ----------
# train Loss: 0.2216 Acc: 0.9081
# val Loss: 0.5178 Acc: 0.7978
#
# Epoch 149/149
# ----------
# train Loss: 0.2224 Acc: 0.9076
# val Loss: 0.5153 Acc: 0.7979
#
# Training complete in 81m 10s
# Best val Acc: 0.802614

# %%
from sklearn.metrics import confusion_matrix

def test_model(model,dataloaders,dataset_size,classes,device):
    
    model=model.to(device)
    model.eval()
    corrects=0
    CM=0
    with torch.no_grad():
        for data in dataloaders['test']:
            images, labels, subject= data
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images) 
            preds = torch.argmax(outputs.data, 1)

            cm_tmp=confusion_matrix(labels.tolist(), preds.tolist(),labels=classes)
            CM+=cm_tmp
            
            corrects += torch.sum(preds == labels.data)
        tn=CM[0][0]
        tp=CM[1][1]
        fp=CM[0][1]
        fn=CM[1][0]
        
        sensitivity=tp/(tp+fn)
        precision=tp/(tp+fp)    
        acc=corrects.double() / dataset_size
        
        print('\nTestset Accuracy(mean): %f %%' % (100 * acc))
        print('Confusion Matrix: ')
        print(CM)
        print('- Sensitivity : ',(tp/(tp+fn))*100)
        print('- Specificity : ',(tn/(tn+fp))*100)
        print('- Precision: ',(tp/(tp+fp))*100)
        print('- NPV: ',(tn/(tn+fn))*100)
        print('- F1 : ',((2*sensitivity*precision)/(sensitivity+precision))*100)
                
    return acc, CM

device_cpu=torch.device('cpu')

print('- model')
acc1,cm1=test_model(trained_model,dataloaders,dataset_sizes['test'],classes=[0,1], device=device_cpu)

print('- model_later')
acc2,cm2=test_model(trained_model_later,dataloaders,dataset_sizes['test'],classes=[0,1], device=device_cpu)
# Out:
# - model
#
# Testset Accuracy(mean): 80.272222 %
# Confusion Matrix:
# [[26411  7005]
#  [ 5996 26490]]
# - Sensitivity :  81.54281844486856
# - Specificity :  79.03698826909265
# - Precision:  79.08643081056874
# - NPV:  81.49782454407998
# - F1 :  80.29584274260772
# - model_later
#
# Testset Accuracy(mean): 80.272222 %
# Confusion Matrix:
# [[26411  7005]
#  [ 5996 26490]]
# - Sensitivity :  81.54281844486856
# - Specificity :  79.03698826909265
# - Precision:  79.08643081056874
# - NPV:  81.49782454407998
# - F1 :  80.29584274260772
