# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/ECE271B_project/
# Out:
# /content/drive/MyDrive/ECE271B_project

# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from modules import train_model, test_model
from dataset import BPDataset, MIMICDataset
from torch import optim
from torch.optim import lr_scheduler
from datetime import datetime
import pandas as pd
from backbone_models import ResNet18, VGG16, shallowResNet, shallowResNet2,ResNet3, FCNet, Conv3Net
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.utils.data as data

# %%
##Dataset paths from part1 to part4
'''data_path=['/Users/yeseullee/Documents/ECE271B/MIMICii/part1',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part2',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part3',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part4']

label_path=['/Users/yeseullee/Documents/ECE271B/MIMICii/part1/label1.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part2/label2.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part3/label3.csv',
'/Users/yeseullee/Documents/ECE271B/MIMICii/part4/label4.csv']'''
data_path='/content/drive/MyDrive/ECE271B_project/MIMICii/dataset_NT_PHT_HT.pt'
label_path='/content/drive/MyDrive/ECE271B_project/MIMICii/label_NT_PHT_HT.pt'
subject_path='/content/drive/MyDrive/ECE271B_project/MIMICii/subjectid_NT_PHT_HT.txt'

# %%
data_mean=1.59
data_std=0.73
data_normalization = {'mean':data_mean,'std':data_std}

# setup data loader
dataset = MIMICDataset(data_path, label_path, subject_path, normalize=data_normalization,preprocessing=False, choose_class=[0,1,2])
dataset_size=dataset.__len__()
print('dataset: {}'.format(dataset.__len__()))
# Out:
# dataset: 528825

# %%
training_size=int(dataset_size*0.64)
test_size=int(dataset_size*0.2)
val_size=dataset_size-training_size-test_size

# %%
# Split training data, validation data, testing data
data_train, data_val, data_test = torch.utils.data.random_split(dataset, [training_size, val_size, test_size])
print(data_train.__len__())
print(data_val.__len__())
print(data_test.__len__())
# Out:
# 338448
# 84612
# 105765

# %%
temp_dataloaders={'train': torch.utils.data.DataLoader(data_train,batch_size=1,shuffle=False),
                'val':torch.utils.data.DataLoader(data_val,batch_size=1,shuffle=False),
                'test':torch.utils.data.DataLoader(data_test,batch_size=1,shuffle=False)}

train_labels=[0,0,0]
for data, label, subject in temp_dataloaders['train']:
    if label.data==0:
        train_labels[0]+=1
    elif label.data==1:
        train_labels[1]+=1
    else:
        train_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),train_labels,color=['g','b','r'],width=0.7)
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Training-set Class Distribution')
plt.show()

val_labels=[0,0,0]
for data, label, subject in temp_dataloaders['val']:
    if label.data==0:
        val_labels[0]+=1
    elif label.data==1:
        val_labels[1]+=1
    else:
        val_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),val_labels,color=['g','b','r'])
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Validation-set Class Distribution')
plt.show()

test_labels=[0,0,0]
for data, label, subject in temp_dataloaders['test']:
    if label.data==0:
        test_labels[0]+=1
    elif label.data==1:
        test_labels[1]+=1
    else:
        test_labels[2]+=1

plt.figure(figsize=(5,3))
plt.bar(np.arange(3),test_labels,color=['g','b','r'])
plt.xticks(np.arange(3),['Normal','Prehypertension','Hypertension'])
plt.title('Test-set Class Distribution')
plt.show()

# %%
dataloaders={'train': torch.utils.data.DataLoader(data_train,batch_size=32,shuffle=True),
                'val':torch.utils.data.DataLoader(data_val,batch_size=32,shuffle=True),
                'test':torch.utils.data.DataLoader(data_test,batch_size=32,shuffle=False)}
dataset_sizes = {'train': data_train.__len__(),
                    'val':data_val.__len__(),
                    'test':data_test.__len__()}  

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device:',device)
# Out:
# Device: cuda

# %%
model=Conv3Net(3)
model=model.to(device)

# %%
learning_rate=0.001
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0005)
#optimizer = optim.Adam(model.parameters(), lr=learning_rate) #weight_decay=0.01
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.2)
trained_model,trained_model_later=train_model(model, criterion, optimizer, exp_lr_scheduler, dataloaders, dataset_sizes, device, num_epochs=150)
# Out:
# Epoch 0/149
# ----------
# train Loss: 1.0062 Acc: 0.4809
# val Loss: 0.9348 Acc: 0.5393
#
# Epoch 1/149
# ----------
# train Loss: 0.9263 Acc: 0.5484
# val Loss: 0.8961 Acc: 0.5729
#
# Epoch 2/149
# ----------
# train Loss: 0.8883 Acc: 0.5751
# val Loss: 0.8509 Acc: 0.5975
#
# Epoch 3/149
# ----------
# train Loss: 0.8651 Acc: 0.5894
# val Loss: 0.8540 Acc: 0.5912
#
# Epoch 4/149
# ----------
# train Loss: 0.8498 Acc: 0.5993
# val Loss: 0.8327 Acc: 0.6109
#
# Epoch 5/149
# ----------
# train Loss: 0.8386 Acc: 0.6064
# val Loss: 0.8454 Acc: 0.6010
#
# Epoch 6/149
# ----------
# train Loss: 0.8320 Acc: 0.6107
# val Loss: 0.8338 Acc: 0.6030
#
# Epoch 7/149
# ----------
# train Loss: 0.8259 Acc: 0.6161
# val Loss: 0.8171 Acc: 0.6205
#
# Epoch 8/149
# ----------
# train Loss: 0.8196 Acc: 0.6196
# val Loss: 0.8139 Acc: 0.6273
#
# Epoch 9/149
# ----------
# train Loss: 0.8169 Acc: 0.6207
# val Loss: 0.7911 Acc: 0.6337
#
# Epoch 10/149
# ----------
# train Loss: 0.8131 Acc: 0.6235
# val Loss: 0.8049 Acc: 0.6272
#
# Epoch 11/149
# ----------
# train Loss: 0.8114 Acc: 0.6244
# val Loss: 0.8181 Acc: 0.6173
#
# Epoch 12/149
# ----------
# train Loss: 0.8083 Acc: 0.6253
# val Loss: 0.7928 Acc: 0.6343
#
# Epoch 13/149
# ----------
# train Loss: 0.8055 Acc: 0.6274
# val Loss: 0.8043 Acc: 0.6228
#
# Epoch 14/149
# ----------
# train Loss: 0.8045 Acc: 0.6275
# val Loss: 0.7793 Acc: 0.6457
#
# Epoch 15/149
# ----------
# train Loss: 0.8019 Acc: 0.6308
# val Loss: 0.8118 Acc: 0.6184
#
# Epoch 16/149
# ----------
# train Loss: 0.8017 Acc: 0.6306
# val Loss: 0.7972 Acc: 0.6288
#
# Epoch 17/149
# ----------
# train Loss: 0.7999 Acc: 0.6316
# val Loss: 0.7925 Acc: 0.6270
#
# Epoch 18/149
# ----------
# train Loss: 0.7996 Acc: 0.6313
# val Loss: 0.7992 Acc: 0.6246
#
# Epoch 19/149
# ----------
# train Loss: 0.7980 Acc: 0.6331
# val Loss: 0.8012 Acc: 0.6261
#
# Epoch 20/149
# ----------
# train Loss: 0.7987 Acc: 0.6328
# val Loss: 0.7839 Acc: 0.6406
#
# Epoch 21/149
# ----------
# train Loss: 0.7976 Acc: 0.6332
# val Loss: 0.8056 Acc: 0.6228
#
# Epoch 22/149
# ----------
# train Loss: 0.7954 Acc: 0.6339
# val Loss: 0.7743 Acc: 0.6453
#
# Epoch 23/149
# ----------
# train Loss: 0.7958 Acc: 0.6338
# val Loss: 0.7782 Acc: 0.6392
#
# Epoch 24/149
# ----------
# train Loss: 0.7948 Acc: 0.6351
# val Loss: 0.7768 Acc: 0.6439
#
# Epoch 25/149
# ----------
# train Loss: 0.7930 Acc: 0.6357
# val Loss: 0.7806 Acc: 0.6403
#
# Epoch 26/149
# ----------
# train Loss: 0.7936 Acc: 0.6348
# val Loss: 0.7854 Acc: 0.6383
#
# Epoch 27/149
# ----------
# train Loss: 0.7931 Acc: 0.6353
# val Loss: 0.7634 Acc: 0.6469
#
# Epoch 28/149
# ----------
# train Loss: 0.7924 Acc: 0.6361
# val Loss: 0.7863 Acc: 0.6396
#
# Epoch 29/149
# ----------
# train Loss: 0.7924 Acc: 0.6361
# val Loss: 0.8025 Acc: 0.6256
#
# Epoch 30/149
# ----------
# train Loss: 0.6944 Acc: 0.6907
# val Loss: 0.6891 Acc: 0.6925
#
# Epoch 31/149
# ----------
# train Loss: 0.6710 Acc: 0.7046
# val Loss: 0.6771 Acc: 0.7015
#
# Epoch 32/149
# ----------
# train Loss: 0.6592 Acc: 0.7110
# val Loss: 0.6717 Acc: 0.7045
#
# Epoch 33/149
# ----------
# train Loss: 0.6518 Acc: 0.7155
# val Loss: 0.6687 Acc: 0.7052
#
# Epoch 34/149
# ----------
# train Loss: 0.6455 Acc: 0.7184
# val Loss: 0.6724 Acc: 0.7033
#
# Epoch 35/149
# ----------
# train Loss: 0.6411 Acc: 0.7206
# val Loss: 0.6791 Acc: 0.7007
#
# Epoch 36/149
# ----------
# train Loss: 0.6379 Acc: 0.7228
# val Loss: 0.6818 Acc: 0.6962
#
# Epoch 37/149
# ----------
# train Loss: 0.6345 Acc: 0.7247
# val Loss: 0.6671 Acc: 0.7077
#
# Epoch 38/149
# ----------
# train Loss: 0.6317 Acc: 0.7261
# val Loss: 0.6765 Acc: 0.7041
#
# Epoch 39/149
# ----------
# train Loss: 0.6301 Acc: 0.7269
# val Loss: 0.6715 Acc: 0.7078
#
# Epoch 40/149
# ----------
# train Loss: 0.6284 Acc: 0.7280
# val Loss: 0.6734 Acc: 0.7052
#
# Epoch 41/149
# ----------
# train Loss: 0.6261 Acc: 0.7289
# val Loss: 0.6719 Acc: 0.7076
#
# Epoch 42/149
# ----------
# train Loss: 0.6256 Acc: 0.7297
# val Loss: 0.6630 Acc: 0.7103
#
# Epoch 43/149
# ----------
# train Loss: 0.6230 Acc: 0.7300
# val Loss: 0.6635 Acc: 0.7103
#
# Epoch 44/149
# ----------
# train Loss: 0.6214 Acc: 0.7318
# val Loss: 0.6682 Acc: 0.7078
#
# Epoch 45/149
# ----------
# train Loss: 0.6199 Acc: 0.7322
# val Loss: 0.6758 Acc: 0.7066
#
# Epoch 46/149
# ----------
# train Loss: 0.6190 Acc: 0.7333
# val Loss: 0.6683 Acc: 0.7071
#
# Epoch 47/149
# ----------
# train Loss: 0.6165 Acc: 0.7338
# val Loss: 0.6559 Acc: 0.7138
#
# Epoch 48/149
# ----------
# train Loss: 0.6165 Acc: 0.7346
# val Loss: 0.6598 Acc: 0.7118
#
# Epoch 49/149
# ----------
# train Loss: 0.6156 Acc: 0.7348
# val Loss: 0.6580 Acc: 0.7134
#
# Epoch 50/149
# ----------
# train Loss: 0.6140 Acc: 0.7354
# val Loss: 0.6661 Acc: 0.7096
#
# Epoch 51/149
# ----------
# train Loss: 0.6130 Acc: 0.7367
# val Loss: 0.6648 Acc: 0.7103
#
# Epoch 52/149
# ----------
# train Loss: 0.6106 Acc: 0.7367
# val Loss: 0.6695 Acc: 0.7050
#
# Epoch 53/149
# ----------
# train Loss: 0.6102 Acc: 0.7380
# val Loss: 0.6720 Acc: 0.7091
#
# Epoch 54/149
# ----------
# train Loss: 0.6088 Acc: 0.7387
# val Loss: 0.6811 Acc: 0.7007
#
# Epoch 55/149
# ----------
# train Loss: 0.6079 Acc: 0.7394
# val Loss: 0.6604 Acc: 0.7092
#
# Epoch 56/149
# ----------
# train Loss: 0.6075 Acc: 0.7390
# val Loss: 0.6797 Acc: 0.7037
#
# Epoch 57/149
# ----------
# train Loss: 0.6065 Acc: 0.7401
# val Loss: 0.6712 Acc: 0.7096
#
# Epoch 58/149
# ----------
# train Loss: 0.6050 Acc: 0.7403
# val Loss: 0.6625 Acc: 0.7109
#
# Epoch 59/149
# ----------
# train Loss: 0.6048 Acc: 0.7392
# val Loss: 0.6602 Acc: 0.7125
#
# Epoch 60/149
# ----------
# train Loss: 0.5482 Acc: 0.7690
# val Loss: 0.6346 Acc: 0.7300
#
# Epoch 61/149
# ----------
# train Loss: 0.5386 Acc: 0.7742
# val Loss: 0.6304 Acc: 0.7305
#
# Epoch 62/149
# ----------
# train Loss: 0.5347 Acc: 0.7757
# val Loss: 0.6315 Acc: 0.7309
#
# Epoch 63/149
# ----------
# train Loss: 0.5325 Acc: 0.7779
# val Loss: 0.6365 Acc: 0.7292
#
# Epoch 64/149
# ----------
# train Loss: 0.5295 Acc: 0.7784
# val Loss: 0.6348 Acc: 0.7301
#
# Epoch 65/149
# ----------
# train Loss: 0.5271 Acc: 0.7789
# val Loss: 0.6352 Acc: 0.7301
#
# Epoch 66/149
# ----------
# train Loss: 0.5261 Acc: 0.7802
# val Loss: 0.6350 Acc: 0.7307
#
# Epoch 67/149
# ----------
# train Loss: 0.5251 Acc: 0.7808
# val Loss: 0.6346 Acc: 0.7299
#
# Epoch 68/149
# ----------
# train Loss: 0.5242 Acc: 0.7813
# val Loss: 0.6346 Acc: 0.7312
#
# Epoch 69/149
# ----------
# train Loss: 0.5223 Acc: 0.7825
# val Loss: 0.6351 Acc: 0.7308
#
# Epoch 70/149
# ----------
# train Loss: 0.5214 Acc: 0.7827
# val Loss: 0.6361 Acc: 0.7309
#
# Epoch 71/149
# ----------
# train Loss: 0.5194 Acc: 0.7835
# val Loss: 0.6366 Acc: 0.7301
#
# Epoch 72/149
# ----------
# train Loss: 0.5183 Acc: 0.7838
# val Loss: 0.6381 Acc: 0.7293
#
# Epoch 73/149
# ----------
# train Loss: 0.5181 Acc: 0.7845
# val Loss: 0.6366 Acc: 0.7309
#
# Epoch 74/149
# ----------
# train Loss: 0.5173 Acc: 0.7847
# val Loss: 0.6410 Acc: 0.7301
#
# Epoch 75/149
# ----------
# train Loss: 0.5165 Acc: 0.7849
# val Loss: 0.6380 Acc: 0.7312
#
# Epoch 76/149
# ----------
# train Loss: 0.5145 Acc: 0.7856
# val Loss: 0.6349 Acc: 0.7308
#
# Epoch 77/149
# ----------
# train Loss: 0.5156 Acc: 0.7851
# val Loss: 0.6393 Acc: 0.7296
#
# Epoch 78/149
# ----------
# train Loss: 0.5139 Acc: 0.7857
# val Loss: 0.6424 Acc: 0.7306
#
# Epoch 79/149
# ----------
# train Loss: 0.5144 Acc: 0.7861
# val Loss: 0.6456 Acc: 0.7284
#
# Epoch 80/149
# ----------
# train Loss: 0.5132 Acc: 0.7865
# val Loss: 0.6439 Acc: 0.7299
#
# Epoch 81/149
# ----------
# train Loss: 0.5123 Acc: 0.7872
# val Loss: 0.6391 Acc: 0.7316
#
# Epoch 82/149
# ----------
# train Loss: 0.5113 Acc: 0.7876
# val Loss: 0.6430 Acc: 0.7289
#
# Epoch 83/149
# ----------
# train Loss: 0.5108 Acc: 0.7873
# val Loss: 0.6394 Acc: 0.7313
#
# Epoch 84/149
# ----------
# train Loss: 0.5106 Acc: 0.7879
# val Loss: 0.6405 Acc: 0.7307
#
# Epoch 85/149
# ----------
# train Loss: 0.5094 Acc: 0.7885
# val Loss: 0.6431 Acc: 0.7292
#
# Epoch 86/149
# ----------
# train Loss: 0.5089 Acc: 0.7882
# val Loss: 0.6450 Acc: 0.7306
#
# Epoch 87/149
# ----------
# train Loss: 0.5081 Acc: 0.7884
# val Loss: 0.6489 Acc: 0.7285
#
# Epoch 88/149
# ----------
# train Loss: 0.5084 Acc: 0.7886
# val Loss: 0.6457 Acc: 0.7289
#
# Epoch 89/149
# ----------
# train Loss: 0.5082 Acc: 0.7886
# val Loss: 0.6429 Acc: 0.7307
#
# Epoch 90/149
# ----------
# train Loss: 0.4949 Acc: 0.7960
# val Loss: 0.6412 Acc: 0.7325
#
# Epoch 91/149
# ----------
# train Loss: 0.4939 Acc: 0.7964
# val Loss: 0.6410 Acc: 0.7314
#
# Epoch 92/149
# ----------
# train Loss: 0.4937 Acc: 0.7965
# val Loss: 0.6422 Acc: 0.7319
#
# Epoch 93/149
# ----------
# train Loss: 0.4938 Acc: 0.7963
# val Loss: 0.6418 Acc: 0.7320
#
# Epoch 94/149
# ----------
# train Loss: 0.4928 Acc: 0.7973
# val Loss: 0.6413 Acc: 0.7321
#
# Epoch 95/149
# ----------
# train Loss: 0.4926 Acc: 0.7970
# val Loss: 0.6417 Acc: 0.7319
#
# Epoch 96/149
# ----------
# train Loss: 0.4927 Acc: 0.7974
# val Loss: 0.6421 Acc: 0.7316
#
# Epoch 97/149
# ----------
# train Loss: 0.4930 Acc: 0.7976
# val Loss: 0.6436 Acc: 0.7320
#
# Epoch 98/149
# ----------
# train Loss: 0.4924 Acc: 0.7972
# val Loss: 0.6425 Acc: 0.7321
#
# Epoch 99/149
# ----------
# train Loss: 0.4919 Acc: 0.7974
# val Loss: 0.6425 Acc: 0.7311
#
# Epoch 100/149
# ----------
# train Loss: 0.4925 Acc: 0.7976
# val Loss: 0.6432 Acc: 0.7315
#
# Epoch 101/149
# ----------
# train Loss: 0.4918 Acc: 0.7978
# val Loss: 0.6438 Acc: 0.7316
#
# Epoch 102/149
# ----------
# train Loss: 0.4923 Acc: 0.7976
# val Loss: 0.6427 Acc: 0.7320
#
# Epoch 103/149
# ----------
# train Loss: 0.4915 Acc: 0.7977
# val Loss: 0.6431 Acc: 0.7320
#
# Epoch 104/149
# ----------
# train Loss: 0.4917 Acc: 0.7976
# val Loss: 0.6426 Acc: 0.7319
#
# Epoch 105/149
# ----------
# train Loss: 0.4918 Acc: 0.7977
# val Loss: 0.6434 Acc: 0.7319
#
# Epoch 106/149
# ----------
# train Loss: 0.4910 Acc: 0.7979
# val Loss: 0.6426 Acc: 0.7315
#
# Epoch 107/149
# ----------
# train Loss: 0.4913 Acc: 0.7976
# val Loss: 0.6439 Acc: 0.7317
#
# Epoch 108/149
# ----------
# train Loss: 0.4912 Acc: 0.7979
# val Loss: 0.6444 Acc: 0.7321
#
# Epoch 109/149
# ----------
# train Loss: 0.4909 Acc: 0.7981
# val Loss: 0.6431 Acc: 0.7317
#
# Epoch 110/149
# ----------
# train Loss: 0.4912 Acc: 0.7980
# val Loss: 0.6439 Acc: 0.7322
#
# Epoch 111/149
# ----------
# train Loss: 0.4903 Acc: 0.7981
# val Loss: 0.6434 Acc: 0.7313
#
# Epoch 112/149
# ----------
# train Loss: 0.4904 Acc: 0.7984
# val Loss: 0.6447 Acc: 0.7318
#
# Epoch 113/149
# ----------
# train Loss: 0.4908 Acc: 0.7977
# val Loss: 0.6442 Acc: 0.7321
#
# Epoch 114/149
# ----------
# train Loss: 0.4901 Acc: 0.7984
# val Loss: 0.6452 Acc: 0.7317
#
# Epoch 115/149
# ----------
# train Loss: 0.4900 Acc: 0.7989
# val Loss: 0.6451 Acc: 0.7318
#
# Epoch 116/149
# ----------
# train Loss: 0.4909 Acc: 0.7977
# val Loss: 0.6449 Acc: 0.7318
#
# Epoch 117/149
# ----------
# train Loss: 0.4906 Acc: 0.7985
# val Loss: 0.6450 Acc: 0.7309
#
# Epoch 118/149
# ----------
# train Loss: 0.4905 Acc: 0.7988
# val Loss: 0.6439 Acc: 0.7320
#
# Epoch 119/149
# ----------
# train Loss: 0.4895 Acc: 0.7985
# val Loss: 0.6440 Acc: 0.7318
#
# Epoch 120/149
# ----------
# train Loss: 0.4884 Acc: 0.7992
# val Loss: 0.6440 Acc: 0.7315
#
# Epoch 121/149
# ----------
# train Loss: 0.4878 Acc: 0.7998
# val Loss: 0.6444 Acc: 0.7314
#
# Epoch 122/149
# ----------
# train Loss: 0.4886 Acc: 0.7998
# val Loss: 0.6444 Acc: 0.7316
#
# Epoch 123/149
# ----------
# train Loss: 0.4884 Acc: 0.7987
# val Loss: 0.6441 Acc: 0.7316
#
# Epoch 124/149
# ----------
# train Loss: 0.4881 Acc: 0.7995
# val Loss: 0.6439 Acc: 0.7311
#
# Epoch 125/149
# ----------
# train Loss: 0.4884 Acc: 0.7990
# val Loss: 0.6433 Acc: 0.7321
#
# Epoch 126/149
# ----------
# train Loss: 0.4883 Acc: 0.7997
# val Loss: 0.6439 Acc: 0.7314
#
# Epoch 127/149
# ----------
# train Loss: 0.4881 Acc: 0.7995
# val Loss: 0.6444 Acc: 0.7316
#
# Epoch 128/149
# ----------
# train Loss: 0.4887 Acc: 0.7994
# val Loss: 0.6439 Acc: 0.7312
#
# Epoch 129/149
# ----------
# train Loss: 0.4880 Acc: 0.7993
# val Loss: 0.6449 Acc: 0.7316
#
# Epoch 130/149
# ----------
# train Loss: 0.4877 Acc: 0.7999
# val Loss: 0.6452 Acc: 0.7316
#
# Epoch 131/149
# ----------
# train Loss: 0.4885 Acc: 0.7992
# val Loss: 0.6456 Acc: 0.7320
#
# Epoch 132/149
# ----------
# train Loss: 0.4881 Acc: 0.7994
# val Loss: 0.6443 Acc: 0.7319
#
# Epoch 133/149
# ----------
# train Loss: 0.4886 Acc: 0.7996
# val Loss: 0.6440 Acc: 0.7321
#
# Epoch 134/149
# ----------
# train Loss: 0.4883 Acc: 0.8000
# val Loss: 0.6447 Acc: 0.7317
#
# Epoch 135/149
# ----------
# train Loss: 0.4883 Acc: 0.7998
# val Loss: 0.6450 Acc: 0.7321
#
# Epoch 136/149
# ----------
# train Loss: 0.4879 Acc: 0.7994
# val Loss: 0.6441 Acc: 0.7318
#
# Epoch 137/149
# ----------
# train Loss: 0.4876 Acc: 0.7996
# val Loss: 0.6441 Acc: 0.7312
#
# Epoch 138/149
# ----------
# train Loss: 0.4880 Acc: 0.7990
# val Loss: 0.6443 Acc: 0.7318
#
# Epoch 139/149
# ----------
# train Loss: 0.4884 Acc: 0.7995
# val Loss: 0.6444 Acc: 0.7319
#
# Epoch 140/149
# ----------
# train Loss: 0.4877 Acc: 0.7998
# val Loss: 0.6444 Acc: 0.7318
#
# Epoch 141/149
# ----------
# train Loss: 0.4878 Acc: 0.7995
# val Loss: 0.6444 Acc: 0.7319
#
# Epoch 142/149
# ----------
# train Loss: 0.4879 Acc: 0.7992
# val Loss: 0.6441 Acc: 0.7317
#
# Epoch 143/149
# ----------
# train Loss: 0.4879 Acc: 0.7997
# val Loss: 0.6440 Acc: 0.7318
#
# Epoch 144/149
# ----------
# train Loss: 0.4877 Acc: 0.7992
# val Loss: 0.6456 Acc: 0.7317
#
# Epoch 145/149
# ----------
# train Loss: 0.4880 Acc: 0.7997
# val Loss: 0.6451 Acc: 0.7325
#
# Epoch 146/149
# ----------
# train Loss: 0.4879 Acc: 0.7998
# val Loss: 0.6450 Acc: 0.7316
#
# Epoch 147/149
# ----------
# train Loss: 0.4883 Acc: 0.7994
# val Loss: 0.6442 Acc: 0.7320
#
# Epoch 148/149
# ----------
# train Loss: 0.4884 Acc: 0.7992
# val Loss: 0.6446 Acc: 0.7317
#
# Epoch 149/149
# ----------
# train Loss: 0.4879 Acc: 0.7993
# val Loss: 0.6435 Acc: 0.7318
#
# Training complete in 126m 5s
# Best val Acc: 0.732544

# %%
from sklearn.metrics import confusion_matrix

def test_model(model,dataloaders,dataset_size,classes,device):
    
    model=model.to(device) 
    model.eval()
    corrects=0
    CM=0
    with torch.no_grad():
        for data in dataloaders['test']:
            images, labels, subject= data
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images) 
            preds = torch.argmax(outputs.data, 1)

            cm_tmp=confusion_matrix(labels.tolist(), preds.tolist(),labels=classes)
            CM+=cm_tmp
            
            corrects += torch.sum(preds == labels.data)
        tn=CM[0][0]
        tp=CM[1][1]
        fp=CM[0][1]
        fn=CM[1][0]
        
        sensitivity=tp/(tp+fn)
        precision=tp/(tp+fp)    
        acc=corrects.double() / dataset_size
        
        print('\nTestset Accuracy(mean): %f %%' % (100 * acc))
        print('Confusion Matrix: ')
        print(CM)
        print('- Sensitivity : ',(tp/(tp+fn))*100)
        print('- Specificity : ',(tn/(tn+fp))*100)
        print('- Precision: ',(tp/(tp+fp))*100)
        print('- NPV: ',(tn/(tn+fn))*100)
        print('- F1 : ',((2*sensitivity*precision)/(sensitivity+precision))*100)
                
    return acc, CM

device_cpu=torch.device('cpu')

print('- model')
acc1,cm1=test_model(trained_model,dataloaders,dataset_sizes['test'],classes=[0,1,2], device=device_cpu)

print('- model_later')
acc2,cm2=test_model(trained_model_later,dataloaders,dataset_sizes['test'],classes=[0,1,2], device=device_cpu)
# Out:
# - model
#
# Testset Accuracy(mean): 72.860587 %
# Confusion Matrix:
# [[24915  5262  3313]
#  [ 4855 20049  7444]
#  [ 2205  5625 32097]]
# - Sensitivity :  80.5051397365885
# - Specificity :  82.56287901381847
# - Precision:  79.21061988858598
# - NPV:  83.691635875042
# - F1 :  79.85263367519666
# - model_later
#
# Testset Accuracy(mean): 72.860587 %
# Confusion Matrix:
# [[24915  5262  3313]
#  [ 4855 20049  7444]
#  [ 2205  5625 32097]]
# - Sensitivity :  80.5051397365885
# - Specificity :  82.56287901381847
# - Precision:  79.21061988858598
# - NPV:  83.691635875042
# - F1 :  79.85263367519666

# %%
model_path='/content/drive/MyDrive/ECE271B_project/models/'
model_name='shallowPPG_MIMIC[0,1,2]_'
torch.save(trained_model.state_dict(),model_path+model_name+datetime.today().strftime('%m-%d-%H:%M')+'.pt')
